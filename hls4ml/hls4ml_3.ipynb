# %%
from tensorflow.keras.utils import to_categorical
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
import numpy as np

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l1
from callbacks import all_callbacks
from qkeras.qlayers import QDense, QActivation
from qkeras.quantizers import quantized_bits, quantized_relu

import plotting
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score

import sys

seed = 0
np.random.seed(seed)
import tensorflow as tf

tf.random.set_seed(seed)
import os

# os.environ['PATH'] = os.environ['XILINX_VIVADO'] + '/bin:' + os.environ['PATH']

# %% [markdown]
# # Open training and testing data

# %%
sample_0 = np.load('toymc_0.npy')
sample_1 = np.load('toymc_1.npy')

label_train = sample_0[:,3]
sample_train = sample_0[:,0:3]
label_test = sample_1[:,3]
sample_test = sample_1[:,0:3]

# %% [markdown]
# # Build quantized model with Qkeras

# %%
# For each layer here, we use 16 as total number of bits, and 8 as number of integer bits
# For the relu activation layer, we use 8 bits for quantization


model = Sequential()
model.add(
    QDense(
        16,
        input_shape=(3,),
        name='fc1',
        kernel_quantizer=quantized_bits(16, 8, alpha=1),
        bias_quantizer=quantized_bits(16, 8, alpha=1),
        kernel_initializer='lecun_uniform',
        kernel_regularizer=l1(0.0001),
    )
)
model.add(QActivation(activation=quantized_relu(16), name='relu1'))
model.add(
    QDense(
        32,
        name='fc2',
        kernel_quantizer=quantized_bits(16, 8, alpha=1),
        bias_quantizer=quantized_bits(16, 8, alpha=1),
        kernel_initializer='lecun_uniform',
        kernel_regularizer=l1(0.0001),
    )
)
model.add(QActivation(activation=quantized_relu(16), name='relu2'))
model.add(
    QDense(
        32,
        name='fc3',
        kernel_quantizer=quantized_bits(16, 8, alpha=1),
        bias_quantizer=quantized_bits(16, 8, alpha=1),
        kernel_initializer='lecun_uniform',
        kernel_regularizer=l1(0.0001),
    )
)
model.add(QActivation(activation=quantized_relu(16), name='relu3'))
model.add(
    QDense(
        1,
        name='output',
        kernel_quantizer=quantized_bits(16, 8, alpha=1),
        bias_quantizer=quantized_bits(16, 8, alpha=1),
        kernel_initializer='lecun_uniform',
        kernel_regularizer=l1(0.0001),
    )
)
model.add(Activation(activation='sigmoid', name='sigmoid'))

# %% [markdown]
# # Pruning

# %%
from tensorflow_model_optimization.python.core.sparsity.keras import prune, pruning_callbacks, pruning_schedule
from tensorflow_model_optimization.sparsity.keras import strip_pruning

# Here, 0.1 means that 10% of the weights will be forced to be 0.
pruning_params = {"pruning_schedule": pruning_schedule.ConstantSparsity(0.1, begin_step=2000, frequency=100)}
model = prune.prune_low_magnitude(model, **pruning_params)

# %% [markdown]
# # Do training and save the result when the "Train" flag is true
# # Or it will take the previous trained result

# %%
train = True
if train:
    adam = Adam(learning_rate=0.0001)
    model.compile(optimizer=adam, loss=['binary_crossentropy'], metrics=['accuracy'])
    callbacks = all_callbacks(
        stop_patience=1000,
        lr_factor=0.5,
        lr_patience=10,
        lr_epsilon=0.000001,
        lr_cooldown=2,
        lr_minimum=0.0000001,
        outputDir='my_model_3',
    )
    callbacks.callbacks.append(pruning_callbacks.UpdatePruningStep())
    model.fit(
        sample_train,
        label_train,
        batch_size=1024,
        epochs=30,
        validation_split=0.25,
        shuffle=True,
        callbacks=callbacks.callbacks,
    )
    model = strip_pruning(model)
    model.save('my_model_3/KERAS_check_best_model.keras')
else:
    from tensorflow.keras.models import load_model
    from qkeras.utils import _add_supported_quantized_objects

    co = {}
    _add_supported_quantized_objects(co)
    model = load_model('my_model_3/KERAS_check_best_model.keras', custom_objects=co)
# Out:
# WARNING:tensorflow:`epsilon` argument is deprecated and will be removed, use `min_delta` instead.
# WARNING:tensorflow:`period` argument is deprecated. Please use `save_freq` to specify the frequency in number of batches seen.
# Epoch 1/30
#   1/147 [..............................] - ETA: 9:28 - loss: 0.6769 - accuracy: 0.6797WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0028s vs `on_train_batch_end` time: 0.0073s). Check your callbacks.
# 130/147 [=========================>....] - ETA: 0s - loss: 0.6476 - accuracy: 0.6688
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 1: val_loss improved from inf to 0.98779, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 1: val_loss improved from inf to 0.98779, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 1: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 1: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 5s 8ms/step - loss: 0.6440 - accuracy: 0.6691 - val_loss: 0.9878 - val_accuracy: 0.0219 - lr: 1.0000e-04
# Epoch 2/30
# 147/147 [==============================] - ETA: 0s - loss: 0.5728 - accuracy: 0.7017
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 2: val_loss improved from 0.98779 to 0.91740, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 2: val_loss improved from 0.98779 to 0.91740, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 2: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 2: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 5ms/step - loss: 0.5728 - accuracy: 0.7017 - val_loss: 0.9174 - val_accuracy: 0.2085 - lr: 1.0000e-04
# Epoch 3/30
# 136/147 [==========================>...] - ETA: 0s - loss: 0.4993 - accuracy: 0.7664
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 3: val_loss improved from 0.91740 to 0.80483, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 3: val_loss improved from 0.91740 to 0.80483, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 3: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 3: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 6ms/step - loss: 0.4966 - accuracy: 0.7679 - val_loss: 0.8048 - val_accuracy: 0.3693 - lr: 1.0000e-04
# Epoch 4/30
# 140/147 [===========================>..] - ETA: 0s - loss: 0.4206 - accuracy: 0.8707
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 4: val_loss improved from 0.80483 to 0.68375, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 4: val_loss improved from 0.80483 to 0.68375, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 4: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 4: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 7ms/step - loss: 0.4189 - accuracy: 0.8724 - val_loss: 0.6837 - val_accuracy: 0.7520 - lr: 1.0000e-04
# Epoch 5/30
# 146/147 [============================>.] - ETA: 0s - loss: 0.3430 - accuracy: 0.9175
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 5: val_loss improved from 0.68375 to 0.55535, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 5: val_loss improved from 0.68375 to 0.55535, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 5: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 5: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 6ms/step - loss: 0.3429 - accuracy: 0.9175 - val_loss: 0.5554 - val_accuracy: 0.8292 - lr: 1.0000e-04
# Epoch 6/30
# 138/147 [===========================>..] - ETA: 0s - loss: 0.2816 - accuracy: 0.9368
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 6: val_loss improved from 0.55535 to 0.46194, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 6: val_loss improved from 0.55535 to 0.46194, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 6: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 6: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 6ms/step - loss: 0.2801 - accuracy: 0.9371 - val_loss: 0.4619 - val_accuracy: 0.8554 - lr: 1.0000e-04
# Epoch 7/30
# 137/147 [==========================>...] - ETA: 0s - loss: 0.2369 - accuracy: 0.9461
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 7: val_loss improved from 0.46194 to 0.39041, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 7: val_loss improved from 0.46194 to 0.39041, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 7: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 7: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 6ms/step - loss: 0.2361 - accuracy: 0.9462 - val_loss: 0.3904 - val_accuracy: 0.8969 - lr: 1.0000e-04
# Epoch 8/30
# 133/147 [==========================>...] - ETA: 0s - loss: 0.2110 - accuracy: 0.9524
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 8: val_loss improved from 0.39041 to 0.35448, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 8: val_loss improved from 0.39041 to 0.35448, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 8: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 8: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 7ms/step - loss: 0.2097 - accuracy: 0.9527 - val_loss: 0.3545 - val_accuracy: 0.9041 - lr: 1.0000e-04
# Epoch 9/30
# 146/147 [============================>.] - ETA: 0s - loss: 0.1887 - accuracy: 0.9585
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 9: val_loss improved from 0.35448 to 0.31994, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 9: val_loss improved from 0.35448 to 0.31994, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 9: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 9: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 5ms/step - loss: 0.1886 - accuracy: 0.9586 - val_loss: 0.3199 - val_accuracy: 0.9154 - lr: 1.0000e-04
# Epoch 10/30
# 131/147 [=========================>....] - ETA: 0s - loss: 0.1734 - accuracy: 0.9638
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 10: val_loss improved from 0.31994 to 0.29506, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 10: val_loss improved from 0.31994 to 0.29506, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 10: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 10: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# Epoch 10: saving model to my_model_3/KERAS_check_model_epoch10.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 7ms/step - loss: 0.1727 - accuracy: 0.9639 - val_loss: 0.2951 - val_accuracy: 0.9263 - lr: 1.0000e-04
# Epoch 11/30
# 139/147 [===========================>..] - ETA: 0s - loss: 0.1638 - accuracy: 0.9651
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 11: val_loss improved from 0.29506 to 0.28194, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 11: val_loss improved from 0.29506 to 0.28194, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 11: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 11: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 7ms/step - loss: 0.1637 - accuracy: 0.9651 - val_loss: 0.2819 - val_accuracy: 0.9270 - lr: 1.0000e-04
# Epoch 12/30
# 145/147 [============================>.] - ETA: 0s - loss: 0.1585 - accuracy: 0.9656
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 12: val_loss improved from 0.28194 to 0.28106, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 12: val_loss improved from 0.28194 to 0.28106, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 12: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 12: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 6ms/step - loss: 0.1585 - accuracy: 0.9656 - val_loss: 0.2811 - val_accuracy: 0.9248 - lr: 1.0000e-04
# Epoch 13/30
# 137/147 [==========================>...] - ETA: 0s - loss: 0.1543 - accuracy: 0.9658
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 13: val_loss did not improve from 0.28106
#
# Epoch 13: val_loss did not improve from 0.28106
#
# Epoch 13: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 13: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 6ms/step - loss: 0.1543 - accuracy: 0.9659 - val_loss: 0.2815 - val_accuracy: 0.9236 - lr: 1.0000e-04
# Epoch 14/30
# 146/147 [============================>.] - ETA: 0s - loss: 0.1515 - accuracy: 0.9657
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 14: val_loss improved from 0.28106 to 0.27639, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 14: val_loss improved from 0.28106 to 0.27639, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 14: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 14: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 8ms/step - loss: 0.1516 - accuracy: 0.9657 - val_loss: 0.2764 - val_accuracy: 0.9240 - lr: 1.0000e-04
# Epoch 15/30
# 137/147 [==========================>...] - ETA: 0s - loss: 0.1496 - accuracy: 0.9657
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 15: val_loss improved from 0.27639 to 0.27474, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 15: val_loss improved from 0.27639 to 0.27474, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 15: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 15: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 7ms/step - loss: 0.1493 - accuracy: 0.9658 - val_loss: 0.2747 - val_accuracy: 0.9243 - lr: 1.0000e-04
# Epoch 16/30
# 146/147 [============================>.] - ETA: 0s - loss: 0.1477 - accuracy: 0.9658
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 16: val_loss improved from 0.27474 to 0.27214, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 16: val_loss improved from 0.27474 to 0.27214, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 16: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 16: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 6ms/step - loss: 0.1477 - accuracy: 0.9658 - val_loss: 0.2721 - val_accuracy: 0.9313 - lr: 1.0000e-04
# Epoch 17/30
# 138/147 [===========================>..] - ETA: 0s - loss: 0.1459 - accuracy: 0.9668
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 17: val_loss improved from 0.27214 to 0.27171, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 17: val_loss improved from 0.27214 to 0.27171, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 17: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 17: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 6ms/step - loss: 0.1463 - accuracy: 0.9667 - val_loss: 0.2717 - val_accuracy: 0.9313 - lr: 1.0000e-04
# Epoch 18/30
# 137/147 [==========================>...] - ETA: 0s - loss: 0.1453 - accuracy: 0.9666
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 18: val_loss did not improve from 0.27171
#
# Epoch 18: val_loss did not improve from 0.27171
#
# Epoch 18: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 18: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 6ms/step - loss: 0.1452 - accuracy: 0.9666 - val_loss: 0.2768 - val_accuracy: 0.9296 - lr: 1.0000e-04
# Epoch 19/30
# 146/147 [============================>.] - ETA: 0s - loss: 0.1442 - accuracy: 0.9667
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 19: val_loss did not improve from 0.27171
#
# Epoch 19: val_loss did not improve from 0.27171
#
# Epoch 19: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 19: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 8ms/step - loss: 0.1442 - accuracy: 0.9667 - val_loss: 0.2728 - val_accuracy: 0.9311 - lr: 1.0000e-04
# Epoch 20/30
# 144/147 [============================>.] - ETA: 0s - loss: 0.1436 - accuracy: 0.9665
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 20: val_loss improved from 0.27171 to 0.27001, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 20: val_loss improved from 0.27171 to 0.27001, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 20: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 20: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# Epoch 20: saving model to my_model_3/KERAS_check_model_epoch20.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 10ms/step - loss: 0.1434 - accuracy: 0.9666 - val_loss: 0.2700 - val_accuracy: 0.9304 - lr: 1.0000e-04
# Epoch 21/30
# 137/147 [==========================>...] - ETA: 0s - loss: 0.1430 - accuracy: 0.9660
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 21: val_loss did not improve from 0.27001
#
# Epoch 21: val_loss did not improve from 0.27001
#
# Epoch 21: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 21: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 7ms/step - loss: 0.1425 - accuracy: 0.9663 - val_loss: 0.2785 - val_accuracy: 0.9275 - lr: 1.0000e-04
# Epoch 22/30
# 142/147 [===========================>..] - ETA: 0s - loss: 0.1423 - accuracy: 0.9663
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 22: val_loss improved from 0.27001 to 0.26992, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 22: val_loss improved from 0.27001 to 0.26992, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 22: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 22: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 7ms/step - loss: 0.1422 - accuracy: 0.9664 - val_loss: 0.2699 - val_accuracy: 0.9292 - lr: 1.0000e-04
# Epoch 23/30
# 135/147 [==========================>...] - ETA: 0s - loss: 0.1407 - accuracy: 0.9666
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 23: val_loss improved from 0.26992 to 0.26321, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 23: val_loss improved from 0.26992 to 0.26321, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 23: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 23: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 5ms/step - loss: 0.1411 - accuracy: 0.9663 - val_loss: 0.2632 - val_accuracy: 0.9329 - lr: 1.0000e-04
# Epoch 24/30
# 143/147 [============================>.] - ETA: 0s - loss: 0.1404 - accuracy: 0.9665
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 24: val_loss improved from 0.26321 to 0.26055, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 24: val_loss improved from 0.26321 to 0.26055, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 24: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 24: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 5ms/step - loss: 0.1404 - accuracy: 0.9665 - val_loss: 0.2606 - val_accuracy: 0.9305 - lr: 1.0000e-04
# Epoch 25/30
# 141/147 [===========================>..] - ETA: 0s - loss: 0.1401 - accuracy: 0.9664
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 25: val_loss did not improve from 0.26055
#
# Epoch 25: val_loss did not improve from 0.26055
#
# Epoch 25: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 25: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 5ms/step - loss: 0.1398 - accuracy: 0.9665 - val_loss: 0.2703 - val_accuracy: 0.9295 - lr: 1.0000e-04
# Epoch 26/30
# 137/147 [==========================>...] - ETA: 0s - loss: 0.1392 - accuracy: 0.9664
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 26: val_loss did not improve from 0.26055
#
# Epoch 26: val_loss did not improve from 0.26055
#
# Epoch 26: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 26: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 5ms/step - loss: 0.1390 - accuracy: 0.9665 - val_loss: 0.2629 - val_accuracy: 0.9317 - lr: 1.0000e-04
# Epoch 27/30
# 145/147 [============================>.] - ETA: 0s - loss: 0.1383 - accuracy: 0.9664
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 27: val_loss did not improve from 0.26055
#
# Epoch 27: val_loss did not improve from 0.26055
#
# Epoch 27: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 27: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 5ms/step - loss: 0.1381 - accuracy: 0.9664 - val_loss: 0.2652 - val_accuracy: 0.9313 - lr: 1.0000e-04
# Epoch 28/30
# 145/147 [============================>.] - ETA: 0s - loss: 0.1374 - accuracy: 0.9665
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 28: val_loss did not improve from 0.26055
#
# Epoch 28: val_loss did not improve from 0.26055
#
# Epoch 28: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 28: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 6ms/step - loss: 0.1373 - accuracy: 0.9665 - val_loss: 0.2655 - val_accuracy: 0.9314 - lr: 1.0000e-04
# Epoch 29/30
# 145/147 [============================>.] - ETA: 0s - loss: 0.1368 - accuracy: 0.9666
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 29: val_loss did not improve from 0.26055
#
# Epoch 29: val_loss did not improve from 0.26055
#
# Epoch 29: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 29: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 5ms/step - loss: 0.1367 - accuracy: 0.9667 - val_loss: 0.2623 - val_accuracy: 0.9313 - lr: 1.0000e-04
# Epoch 30/30
# 134/147 [==========================>...] - ETA: 0s - loss: 0.1360 - accuracy: 0.9668
# ***callbacks***
# saving losses to my_model_3/losses.log
#
# Epoch 30: val_loss improved from 0.26055 to 0.25435, saving model to my_model_3/KERAS_check_best_model.h5
#
# Epoch 30: val_loss improved from 0.26055 to 0.25435, saving model to my_model_3/KERAS_check_best_model_weights.h5
#
# Epoch 30: saving model to my_model_3/KERAS_check_model_last.h5
#
# Epoch 30: saving model to my_model_3/KERAS_check_model_last_weights.h5
#
# Epoch 30: saving model to my_model_3/KERAS_check_model_epoch30.h5
#
# ***callbacks end***
#
# 147/147 [==============================] - 1s 5ms/step - loss: 0.1361 - accuracy: 0.9668 - val_loss: 0.2543 - val_accuracy: 0.9322 - lr: 1.0000e-04
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# # Process the testing sample

# %%
y_keras = model.predict(sample_test)
# Out:
# 6250/6250 [==============================] - 9s 1ms/step

# %% [markdown]
# # Check the testing result with a cut on 0.5 and compraing to the expected label

# %%
y_keras_sig = y_keras[ (label_test > 0 ) ]
y_keras_bkg = y_keras[ (label_test < 1) ]

plt.figure(figsize=(6,6))
plt.hist(y_keras_bkg,log=True,bins=50,label='label == 0',alpha=0.5,color='blue')
plt.hist(y_keras_sig,log=True,bins=50,label='label == 1',alpha=0.5,color='red')
plt.legend().get_frame().set_alpha(0)
plt.xlabel('y_keras')
plt.show()

# %%
y_pred_binary = (y_keras > 0.5).astype(int)
accuracy = accuracy_score(label_test, y_pred_binary)
print("Accuracy: {:.2f}%".format(accuracy * 100))

label_test_reshape = label_test.reshape(len(label_test),1)
plt.figure(figsize=(9, 9))
_ = plotting.makeRoc(label_test_reshape, y_keras, ['Signal'])
plt.show()
# Out:
# Accuracy: 95.80%

# %% [markdown]
# # Build hls4ml model

# %%
# To create the text files to be used in later HLS Csimulation
import csv

with open('my_model_3/Input.dat', 'w') as f:
    csv.writer(f, delimiter=' ').writerows(sample_test)

with open('my_model_3/Output.dat', 'w') as f:
    csv.writer(f, delimiter=' ').writerows(y_keras)

# %%
import hls4ml

config = hls4ml.utils.config_from_keras_model(model, granularity='name')

# This is for quantization on the output layer using the HLS options
# After training, you can set the quantization for each layer like this
config['LayerName']['sigmoid']['exp_table_t'] = 'ap_fixed<32,6>'
config['LayerName']['sigmoid']['inv_table_t'] = 'ap_fixed<32,6>'
config['LayerName']['sigmoid']['Precision']='ap_fixed<16,6>'

plotting.print_dict(config)
hls_model = hls4ml.converters.convert_from_keras_model(
    model, hls_config=config, output_dir='my_model_3/hls4ml_prj', part='xc7a200tsbg484-1',
    input_data_tb = "my_model_3/Input.dat",
    output_data_tb = "my_model_3/Output.dat"
)
# "part" is the FPGA part of the Nexys video card
# By default, it will use Vivado HLS for backend
# If you use newer version of Xilinx software, you need to include backend='Vitis' in the argument to use Vitis HLS.
# Use io_type="io_parallel" in the argument to input all the bits in parallel
# Out:
# Interpreting Sequential
# Topology:
# Layer name: fc1_input, layer type: InputLayer, input shapes: [[None, 3]], output shape: [None, 3]
# Layer name: fc1, layer type: QDense, input shapes: [[None, 3]], output shape: [None, 16]
# Layer name: relu1, layer type: Activation, input shapes: [[None, 16]], output shape: [None, 16]
# Layer name: fc2, layer type: QDense, input shapes: [[None, 16]], output shape: [None, 32]
# Layer name: relu2, layer type: Activation, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: fc3, layer type: QDense, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: relu3, layer type: Activation, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: output, layer type: QDense, input shapes: [[None, 32]], output shape: [None, 1]
# Layer name: sigmoid, layer type: Activation, input shapes: [[None, 1]], output shape: [None, 1]
# Model
#   Precision:         fixed<16,6>
#   ReuseFactor:       1
#   Strategy:          Latency
#   BramFactor:        1000000000
#   TraceOutput:       False
# LayerName
#   fc1_input
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#   fc1
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#       weight:        fixed<16,9>
#       bias:          fixed<16,9>
#   fc1_linear
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#   relu1
#     Trace:           False
#     Precision
#       result:        ufixed<16,0,RND_CONV,SAT>
#   fc2
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#       weight:        fixed<16,9>
#       bias:          fixed<16,9>
#   fc2_linear
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#   relu2
#     Trace:           False
#     Precision
#       result:        ufixed<16,0,RND_CONV,SAT>
#   fc3
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#       weight:        fixed<16,9>
#       bias:          fixed<16,9>
#   fc3_linear
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#   relu3
#     Trace:           False
#     Precision
#       result:        ufixed<16,0,RND_CONV,SAT>
#   output
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#       weight:        fixed<16,9>
#       bias:          fixed<16,9>
#   output_linear
#     Trace:           False
#     Precision
#       result:        fixed<16,6>
#   sigmoid
#     Trace:           False
#     Precision:       ap_fixed<16,6>
#     exp_table_t:     ap_fixed<32,6>
#     inv_table_t:     ap_fixed<32,6>
# Interpreting Sequential
# Topology:
# Layer name: fc1_input, layer type: InputLayer, input shapes: [[None, 3]], output shape: [None, 3]
# Layer name: fc1, layer type: QDense, input shapes: [[None, 3]], output shape: [None, 16]
# Layer name: relu1, layer type: Activation, input shapes: [[None, 16]], output shape: [None, 16]
# Layer name: fc2, layer type: QDense, input shapes: [[None, 16]], output shape: [None, 32]
# Layer name: relu2, layer type: Activation, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: fc3, layer type: QDense, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: relu3, layer type: Activation, input shapes: [[None, 32]], output shape: [None, 32]
# Layer name: output, layer type: QDense, input shapes: [[None, 32]], output shape: [None, 1]
# Layer name: sigmoid, layer type: Activation, input shapes: [[None, 1]], output shape: [None, 1]
# Creating HLS model

# %%
# This is to show the hls4ml model structure
from IPython.display import Image
hls4ml.utils.plot_model(hls_model, show_shapes=True, show_precision=True, to_file='hls_model.png')
Image('hls_model.png')

# %%
# Compile it
hls_model.compile()
# Out:
# Writing HLS project
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Done

# %% [markdown]
# # Process the testing data with hls4ml model and see the performance

# %%
y_hls = hls_model.predict(np.ascontiguousarray(sample_test))

y_pred_binary_hls = (y_hls > 0.5).astype(int)
accuracy_hls = accuracy_score(label_test, y_pred_binary_hls)
print("Accuracy Keras: {:.2f}%".format(accuracy * 100))
print("Accuracy HLS: {:.2f}%".format(accuracy_hls * 100))

import matplotlib.pyplot as plt

plt.figure(figsize=(9, 9))
_ = plotting.makeRoc(label_test_reshape, y_keras, ['Signal'])
plt.gca().set_prop_cycle(None)  
_ = plotting.makeRoc(label_test_reshape, y_hls, ['Signal'], linestyle='--')
plt.show()
# Out:
# Accuracy Keras: 95.80%
# Accuracy HLS: 93.43%

# %%
y_hls_sig = y_hls[ (label_test > 0 ) ]
y_hls_bkg = y_hls[ (label_test < 1) ]

plt.figure(figsize=(6,6))
plt.hist(y_hls_bkg,log=True,bins=50,label='label == 0',alpha=0.5,color='blue')
plt.hist(y_hls_sig,log=True,bins=50,label='label == 1',alpha=0.5,color='red')
plt.legend().get_frame().set_alpha(0)
plt.xlabel('yhls')
plt.show()

# %% [markdown]
# # Create the Vivado HLS project and do C simulation

# %%
# This requires the environment variable for Xilinx Vivado being included.
# For instance, you need to run:
# source /tools/Xilinx/Vivado/2019.2/settings64.sh
# Since we set csim and cosim as True to start simulation, it takes few min.
hls_model.build(synth=True,csim=True,cosim=True)

# %%
# The Vivado HLS project will be created
hls4ml.report.read_vivado_report('my_model_3/hls4ml_prj')

# %% [markdown]
# ## Dump the predicted output data from hls4ml model to be compared to the Vivado firmware output

# %%
# This function will change a float into an integer under ap_fixed<N,I> format
def float_to_ap_fixed(value, N, I=8):
    F = N - I
    scaled_value = int(round(value * (1 << F)))
    if scaled_value < 0:
        scaled_value = (1 << N) + scaled_value
    scaled_value = scaled_value & ((1 << N) - 1)
    return int(scaled_value)

# This function will change a integer into hex
def to_hex(value, Nbit):
    return format(int(value), f'0{Nbit // 4}X')

y_hls_16_6 = np.vectorize(float_to_ap_fixed)(y_hls,16,6)
y_hls_hex_16_6 = np.vectorize(to_hex)(y_hls_16_6,16)


Nline = 1024

with open('text_data/predicted_hls_out.mem', 'w') as file0:
    for i in range(0,Nline):
        file0.write(f"{y_hls_hex_16_6[i][0]} \n")
